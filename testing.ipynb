# %%
from Zebrafish_model import *
from PIL import Image

# %%
zebra_model = ZebraMol(save_net_img='zebra_mod.png').net
img = Image.open('zebra_mod.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=787x900 at 0x7F68D802B5B0>

# %%
zebra_model
# Out:
# PetriNet('Zebrafish Paracetamol net')
