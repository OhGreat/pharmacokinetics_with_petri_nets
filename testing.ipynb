# %%
import snakes.plugins
snakes.plugins.load('gv', 'snakes.nets', 'nets')
from Zebrafish_model import *
from PIL import Image

# %%
zebra_model = ZebraMol(save_net_img='zebra_mod.png')
img = Image.open('zebra_mod.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=787x900 at 0x7FA2104F3310>
