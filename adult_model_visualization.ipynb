# %%
import numpy as np
from model_adult import *
import matplotlib.pyplot as plt
from PIL import Image
plt.style.use('seaborn-whitegrid')

# %%
model = AdultModel()
model.save_img('temp/adult_model.png')
Image.open('temp/adult_model.png')
# Out:
# {'k_a': 0.76, 'k_PG,f': 0.565, 'k_PS,f': 0.422, 'k_PC,f': 0.0925, 'k_PC,e': 0.232, 'k_P,e': 0.0154, 'k_G,e': 0.00743, 'k_S,e': 0.000664}
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=564x900>

# %%
# Expreriment 3
p3 = np.load('results/exp3/p_val.npy')
s3 = np.load('results/exp3/s_val.npy')
g3 = np.load('results/exp3/g_val.npy')
cyp3 = np.load('results/exp3/cyp_val.npy')
pe3 = np.load('results/exp3/pe_val.npy')
se3 = np.load('results/exp3/se_val.npy')
ge3 = np.load('results/exp3/ge_val.npy')
cype3 = np.load('results/exp3/cype_val.npy')

# %%
def plots(zipped, title, subtitles, linestyle, labels):
  fig, axis = plt.subplots(2,2, figsize=(20,15))
  fig.tight_layout(pad=5.0)
  # fig.suptitle(title, fontsize=24, fontweight='bold')
  i = 0
  for compound in zipped:
    x = i//2
    y = i%2
    axis[x][y].set_title(subtitles[i], size=22)
    axis[x][y].plot(compound[0], color=compound[1], linewidth=4, linestyle=linestyle, label='Experiment 3')
    axis[x][y].set_xlabel(labels[0][0],  fontsize=18)
    axis[x][y].set_ylabel(labels[0][1],  fontsize=18)
    axis[x][y].set_yscale("log", base=10)
    axis[x][y].set_xscale("linear")
    axis[x][y].legend(prop={'size': 10})
    i += 1
  plt.show()

# %%
subtitles_exposure = [
  'Paracetamol in homogenate',
  'Paracetamol-glucuronide in homogenate',
  'Paracetamol-sulfate in homogenate',
  'Paracetamol-oxidised in homogenate'
]

colors = [
  'blue',
  'magenta',
  'orange',
  'green'
]

labels_exposure = [
  [
    ('Time (min)'),
    ('Compound (pmoles/larva)')
  ] * 4]
 
title_exposure = 'Internal Exposure'

# %%
plots(
    zipped = zip([p3, g3, s3, cyp3], colors),
    title=title_exposure,
    subtitles=subtitles_exposure,
    labels=labels_exposure,
    linestyle='solid'
  )

# %%
title_excreted = 'Excreted Compound'
subtitles_excreted = [
  'Paracetamol excreted',
  'Paracetamol-glucuronide excreted',
  'Paracetamol-sulfate excreted',
  'Paracetamol-oxidised excreted'
]
labels_excreted = [
  [
    ('Time (min)'),
    ('Excreted Compound (pmoles/larva)')
  ]*4
]

plots(
    zipped = zip([pe3, ge3, se3, cype3], colors),
    title=title_excreted,
    subtitles=subtitles_excreted,
    labels=labels_excreted,
    linestyle='solid'
  )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/andreas/Library/Mobile Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb Cell 7' in <cell line: 15>()
#       <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000007?line=1'>2</a> subtitles_excreted = [
#       <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000007?line=2'>3</a>   'Paracetamol excreted',
#       <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000007?line=3'>4</a>   'Paracetamol-glucuronide excreted',
#       <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000007?line=4'>5</a>   'Paracetamol-sulfate excreted'
#       <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000007?line=5'>6</a>   'Paracetamol-oxidised excreted'
#       <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000007?line=6'>7</a> ]
#       <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000007?line=7'>8</a> labels_excreted = [
#       <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000007?line=8'>9</a>   [
#      <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000007?line=9'>10</a>     ('Time (min)'),
#      <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000007?line=10'>11</a>     ('Excreted Compound (pmoles/larva)')
#      <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000007?line=11'>12</a>   ]*4
#      <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000007?line=12'>13</a> ]
# ---> <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000007?line=14'>15</a> plots(
#      <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000007?line=15'>16</a>     zipped = zip([pe3, ge3, se3, cype3], colors),
#      <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000007?line=16'>17</a>     title=title_excreted,
#      <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000007?line=17'>18</a>     subtitles=subtitles_excreted,
#      <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000007?line=18'>19</a>     labels=labels_excreted,
#      <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000007?line=19'>20</a>     linestyle='solid'
#      <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000007?line=20'>21</a>   )
#
# /Users/andreas/Library/Mobile Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb Cell 4' in plots(zipped, title, subtitles, linestyle, labels)
#       <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000003?line=6'>7</a> x = i//2
#       <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000003?line=7'>8</a> y = i%2
# ----> <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000003?line=8'>9</a> axis[x][y].set_title(subtitles[i], size=22)
#      <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000003?line=9'>10</a> axis[x][y].plot(compound[0], color=compound[1], linewidth=4, linestyle=linestyle, label='Experiment 3')
#      <a href='vscode-notebook-cell:/Users/andreas/Library/Mobile%20Documents/com~apple~CloudDocs/workspace/biomodeling_assignment/adult_model_visualization.ipynb#ch0000003?line=10'>11</a> axis[x][y].set_xlabel(labels[0][0],  fontsize=18)
#
# IndexError: list index out of range
